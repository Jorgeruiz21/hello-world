# %% [markdown]
# # Ejercicios de optimización escalar
# ### Jorge Ruiz Esquer
# #### 26/01/2023

# %% [markdown]
# **Para la siguientes funciones encuentre los puntos críticos, grafique y diga si éste se trata de un máximo o mínimo, local o global.**

# %% [markdown]
# $f(x)=1260+117x-9x^2$

# %%
import sympy as sp
import numpy as np
import pandas as pd

sp.var("x")
def f(x):
    return  1260 + 117*x - 9*(x)**2
f(x)
# Out:
# -9*x**2 + 117*x + 1260

# %%
df= sp.diff(f(x), x)
df
# Out:
# 117 - 18*x

# %%
pc= sp.solve(df, x)
pc
# Out:
# [13/2]

# %%
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline

xn= np.linspace(-20,30,1000)
yn= f(xn)


plt.figure()
plt.plot(xn,yn)
plt.grid()
plt.plot(pc[0], f(pc[0]), "*r")

# %% [markdown]
# $f(x)=5+x+\frac{4}{x}$, para $x>0$

# %%
import sympy as sp
import numpy as np
import pandas as pd

sp.var("x")
def f(x):
    return  5 + x + 4/x
f(x)
# Out:
# x + 5 + 4/x

# %%
df= sp.diff(f(x), x)
df
# Out:
# 1 - 4/x**2

# %%
pc= sp.solve(df, x)
pc
# Out:
# [-2, 2]

# %%
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline

xn= np.linspace(1,6,1000)
yn= f(xn)


plt.figure()
plt.plot(xn,yn)
plt.grid()
plt.plot(pc[1], f(pc[1]), "*r")

# %% [markdown]
# $f(x)=6-2x+\sqrt{18-2x^2}$, para $-3\leq x\leq 3$

# %%
import sympy as sp
import numpy as np
import pandas as pd

sp.var("x")
def f(x):
    return  6-2*x+((18)-2*(x**2))**(1/2)
f(x)
# Out:
# -2*x + (18 - 2*x**2)**0.5 + 6

# %%
df= sp.diff(f(x), x)
df
# Out:
# -2.0*x/(18 - 2*x**2)**0.5 - 2

# %%
pc= sp.solve(df, x)
pc
# Out:
# [-2.44948974278318]

# %%
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline

xn= np.linspace(-3,3,1000)
yn= f(xn)


plt.figure()
plt.plot(xn,yn)
plt.grid()
plt.plot(pc[0], f(pc[0]), "*r")

# %% [markdown]
# $f(x)=\frac{1}{4}x^4+\frac{1}{3}x^3-x^2$ en el intervalo $[-3,1.7]$

# %%
import sympy as sp
import numpy as np
import pandas as pd

sp.var("x")
def f(x):
    return  1/4*x**4+1/3*x**3-x**2
f(x)
# Out:
# 0.25*x**4 + 0.333333333333333*x**3 - x**2

# %%
df= sp.diff(f(x), x)
df
# Out:
# 1.0*x**3 + 1.0*x**2 - 2*x

# %%
pc= sp.solve(df, x)
pc
# Out:
# [-2.00000000000000, 0.0, 1.00000000000000]

# %%
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline

xn= np.linspace(-3,1.7,1000)
yn= f(xn)


plt.figure()
plt.plot(xn,yn)
plt.grid()
plt.plot(pc[0], f(pc[0]), "*r")

# %% [markdown]
# ---
# **Resuelva los siguientes problemas usando la librería `SymPy`. Use celdas en `Markdown` para explicar su procedimiento.**

# %% [markdown]
# El perímetro de un triángulo isósceles es de $10 cm$. ¿Cuánto deben medir sus lados para que el volumen del cuerpo generado por la rotación del triángulo en torno a su base sea el mayor posible? (Volumen de un cono $= \frac{1}{3}\pi r^2 h$, donde $r$ es el radio de la base y $h$ la altura del cono).

# %%
import sympy as sp
import numpy as np
import pandas as pd

# %% [markdown]
# Disponemos de una barra de aluminio de 6 metros para construir una portería de fútbol. Si queremos que el área de la portería sea máxima, ¿cuánto deben medir los postes y el travesaño?

# %%
import sympy as sp
import numpy as np
import pandas as pd
sp.var("y")
sp.var("x")
sp.var("A")
sp.var("P")
def f(x):
    return  2*x + y - 6 
def g(x):
    return x*y

# %%
A = g(x).subs(x, (6-y)/2)
A
# Out:
# y*(3 - y/2)

# %%
df= sp.diff(A, y)
df
# Out:
# 3 - y

# %%
pt= sp.solve(df, y)
pt
# Out:
# [3]

# %%
p = f(x).subs(y, 3)
p
# Out:
# 2*x - 3

# %%
pc= sp.solve(p, x)
pc
# Out:
# [3/2]

# %%
print("Para que el área de la porteria sea maxima se necesitan utilizar postes con la medida de " + str(pc) + " y un travesaño de "+ str(pt))
# Out:
# Para que el área de la porteria sea maxima se necesitan utilizar postes con la medida de [3/2] y un travesaño de [3]
